# %%
##Author: Sargon Morad
#Partner: Andrew Garvey
#Date: July 1st, 2019
#Client: Hospital for Sick Children

#Purpose:
#-   Visualize the ED Data

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

from IPython.display import display, HTML

# %%
epic_clean = pd.read_csv(r'ED_Epic_Data/clean_epic.csv', low_memory=False)

# %%
sns.set()
fig, ax = plt.subplots(figsize=(15,7))
fig.suptitle("Order Counts by Month June 2018 - June 2019")
p = sns.countplot(data=epic_clean, x = 'Gender')

# %%
fig, ax = plt.subplots(figsize=(15,7))
fig.suptitle("Order Counts by CTAS June 2018 - June 2019")
p = sns.countplot(data=epic_clean, x = 'CTAS')

# %%
fig, ax = plt.subplots(figsize=(15,7))
fig.suptitle("Order Counts by Acuity June 2018 - June 2019")
p = sns.countplot(data=epic_clean, x = 'Acuity')
